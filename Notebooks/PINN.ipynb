# %%
import numpy as np

import data_visualization as dv

PATH_TIMINGS = "../Models/Timings/PINN.csv"
PATH_METRICS = "../Models/Metrics/PINN.csv"
PATH_RESULTS = "../Models/Results/PINN.npz"

# %%
dv.plot_training_time(PATH_TIMINGS)

# %%
dv.plot_loss_history(PATH_METRICS)

# %%
dv.plot_accuracy_over_time(PATH_RESULTS)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 dv.plot_accuracy_over_time(PATH_RESULTS)
#
# File ~/HP-ML/projects/HPML-Project/Notebooks/data_visualization.py:70, in plot_accuracy_over_time(npz_path)
#      68 def plot_accuracy_over_time(npz_path):
#      69     data = np.load(npz_path)
# ---> 70     lead_times = data['lead_times']
#      71     accuracies = data['accuracies']
#      72     plt.figure(figsize=(8, 6))
#
# File ~/.conda/envs/torch/lib/python3.10/site-packages/numpy/lib/_npyio_impl.py:261, in NpzFile.__getitem__(self, key)
#     259         return self.zip.read(key)
#     260 else:
# --> 261     raise KeyError(f"{key} is not a file in the archive")
#
# KeyError: 'lead_times is not a file in the archive'

# %%
data = np.load(PATH_RESULTS)

print(data)
# Out:
# NpzFile '../Models/Results/PINN.npz' with keys: loss, predictions, targets
