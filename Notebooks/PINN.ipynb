# %%
import data_visualization as dv

PATH_TIMINGS = "../Models/Timings/PINN-Base.csv"
PATH_METRICS = "../Models/Metrics/PINN-Base.csv"
PATH_RESULTS = "../Models/Results/PINN-Base.nc"

# %%
dv.plot_loss_and_training_time(PATH_TIMINGS)

# %%
dv.plot_loss_history(PATH_METRICS)

# %%
dv.plot_accuracy_over_time(PATH_RESULTS)
