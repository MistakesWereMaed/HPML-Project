# %%
import data_visualization as dv

PATH_TIMINGS = "../Models/Timings/FNO.csv"
PATH_METRICS = "../Models/Metrics/FNO_4.csv"
PATH_RESULTS = "../Models/Results/FNO.nc"

# %%
dv.plot_loss_and_training_time(PATH_TIMINGS)

# %%
dv.plot_loss_history(PATH_METRICS)

# %%
dv.plot_accuracy_over_time(PATH_RESULTS)

# %%
dv.plot_prediction_vs_target(PATH_RESULTS, 0, 0, 0)
