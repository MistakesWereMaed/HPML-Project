# %%
import data_visualization as dv

PATH_TIMINGS_PINN = "../Models/Timings/PINN.csv"
PATH_TIMINGS_GNN = "../Models/Timings/GNN.csv"
PATH_TIMINGS_FNO = "../Models/Timings/FNO.csv"

PATH_METRICS_PINN = "../Models/Metrics/PINN_2.csv"
PATH_METRICS_GNN = "../Models/Metrics/GNN_2.csv"
PATH_METRICS_FNO = "../Models/Metrics/FNO_2.csv"

PATH_RESULTS_PINN = "../Models/Results/PINN.nc"
PATH_RESULTS_GNN = "../Models/Results/GNN.nc"
PATH_RESULTS_FNO = "../Models/Results/FNO.nc"

dv.plot_model_metrics_linegraph(PATH_TIMINGS_PINN, PATH_TIMINGS_GNN, PATH_TIMINGS_FNO)
dv.plot_all_loss_histories(PATH_METRICS_PINN, PATH_METRICS_GNN, PATH_METRICS_FNO)
dv.plot_all_accuracy_over_time(PATH_RESULTS_PINN, PATH_RESULTS_GNN, PATH_RESULTS_FNO)
